# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.0)
# Requirement already satisfied: pillow>=8 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\ruhir\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)

# %%
df = pd.read_csv('train.csv')

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 860          861         0       3       Hansen, Mr. Claus Peter    male
# 217          218         0       2  Jacobsohn, Mr. Sidney Samuel    male
# 644          645         1       3        Baclini, Miss. Eugenie  female
# 540          541         1       1       Crosby, Miss. Harriet R  female
# 349          350         0       3              Dimic, Mr. Jovan    male
#
#        Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 860  41.00      2      0     350026  14.1083   NaN        S
# 217  42.00      1      0     243847  27.0000   NaN        S
# 644   0.75      2      1       2666  19.2583   NaN        C
# 540  36.00      0      2  WE/P 5735  71.0000   B22        S
# 349  42.00      0      0     315088   8.6625   NaN        S

# %% [markdown]
# # 1. Categorical Data

# %% [markdown]
# ## a. Countplot

# %%
sns.countplot(df, x="Survived")
#df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# ## b. PieChart

# %%
df['Pclass'].value_counts().plot(kind='pie', autopct="%.2f")
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## a. Histogram

# %%
plt.hist(df["Age"])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## b. Displot

# %%
sns.displot(df['Age'],kde=True)

# %% [markdown]
# ## c. Boxplot

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>
