# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('covid_toy.csv')

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['has_covid']),df['has_covid'],
                                                test_size=0.2)

# %%
X_train
# Out:
#     age  gender  fever   cough       city
# 41   82    Male    NaN    Mild    Kolkata
# 73   34    Male   98.0  Strong    Kolkata
# 37   55    Male  100.0    Mild    Kolkata
# 39   50  Female  103.0    Mild    Kolkata
# 81   65    Male   99.0    Mild      Delhi
# ..  ...     ...    ...     ...        ...
# 36   38  Female  101.0    Mild  Bangalore
# 12   25  Female   99.0  Strong    Kolkata
# 44   20    Male  102.0  Strong      Delhi
# 54   60  Female   99.0    Mild     Mumbai
# 13   64    Male  102.0    Mild  Bangalore
#
# [80 rows x 5 columns]

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
from sklearn.compose import ColumnTransformer

# %%
transformer=ColumnTransformer(transformers=[
    ('tr1',SimpleImputer(),['fever']), #filling missing values
    ('tr2',OrdinalEncoder(categories=[['Mild','Strong']]),['cough']), #Ordinal data(Categorical data) --> OrdinalEncoder
    ('tr3',OneHotEncoder(sparse_output=False,drop='first'),['gender','city']) #Nominal data(Categorical data) --> OneHotEncoder
],remainder='passthrough') #Age would be passthrough

# %%
transformer.fit_transform(X_train)
# Out:
# array([[101.05633803,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  82.        ],
#        [ 98.        ,   1.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  34.        ],
#        [100.        ,   0.        ,   1.        ,   0.        ,
#           1.        ,   0.        ,  55.        ],
#        [103.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  50.        ],
#        [ 99.        ,   0.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,  65.        ],
#        [ 98.        ,   1.        ,   1.        ,   0.        ,
#           0.        ,   0.        ,  12.        ],
#        [101.        ,   0.        ,   1.        ,   1.        ,
#           0.        ,   0.        ,  15.        ],
#        [103.        ,   0.        ,   0.        ,   0.        ,
#           1.        ,   0.        ,  69.        ],
# ...

# %%
transformer.fit_transform(X_train).shape
# Out:
# (80, 7)

# %%
transformer.transform(X_test).shape
# Out:
# (20, 7)
